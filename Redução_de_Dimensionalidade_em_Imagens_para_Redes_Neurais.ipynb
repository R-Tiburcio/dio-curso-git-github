# %% [markdown]
# <a href="https://colab.research.google.com/github/R-Tiburcio/dio-curso-git-github/blob/main/Redu%C3%A7%C3%A3o_de_Dimensionalidade_em_Imagens_para_Redes_Neurais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Redução de Dimensionalidade em Imagens para Redes Neurais**
#
#
# Objetivo: Converter uma imagem RGB para tons de cinza, em seguida transformar a imagem em tons de cinza para binária

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

img = mpimg.imread("MODELO.png")
imgplot = plt.imshow(img)
plt.show()

# %%
#Convertendo imagem em tons de cinza
img = np.dot(img[...,:3], [0.2989, 0.5870, 0.1140])

# %%
#mostrando imagem em tons de cinza
plt.imshow(img, cmap = plt.get_cmap(name = 'gray'))

# %%
#Salvando imagem em tons de cinza
mpimg.imsave("modelo_cinza.png", img)

# %%
#convertendo a imagem para binário
#pixels com valores acima de 150 serão convertidos para 1, o resto fica em 0
modelo_binario = 1 * (img > 150)

#Mostrando a imagem binária
plt.imshow(modelo_binario, cmap = plt.get_cmap(name = 'gray'))
